# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn.metrics import confusion_matrix

# %%
import requests

# %%
URL = 'https://www.monster.com/jobs/search/?q=data-scientist&where=united-states'
page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en" xml:lang="en" xmlns="https://www.w3.org/1999/xhtml">
# <head>
# <link href="https://coda.newjobs.com" rel="preconnect"/>
# <link href="https://js-seeker.newjobs.com" rel="preconnect"/>
# <link href="https://css-seeker.newjobs.com" rel="preconnect"/>
# <link href="https://securemedia.newjobs.com" rel="preconnect"/>
# <link href="https://logs2.jobs.com" rel="preconnect"/>
# <link href="https://job-openings.monster.com" rel="preconnect"/>
# <link href="https://apis.google.com" rel="preconnect"/>
# <link href="https://www.google.com" rel="preconnect"/>
# <link href="https://accounts.google.com" rel="preconnect"/>
# <link href="https://content.googleapis.com" rel="preconnect"/>
# <link href="https://ssl.gstatic.com" rel="preconnect"/>
# <link href="https://www.dropbox.com" rel="preconnect"/>
# <link href="http://js.live.net" rel="preconnect"/>
# <link href="https://r.turn.com" rel="preconnect"/>
# ...

# %%
match=soup.title.text
print(match)
# Out:
# Data Scientist Jobs in united states. united states Data Scientist Jobs. | Monster.com

# %%
results = soup.find(id='mainContent')

# %%
print(results.prettify())
# Out:
# <main class="page-content" id="mainContent">
#  <div class="row">
#   <div class="col-md-4 list-only">
#    <div class="mux-custom-scroll" data-extend="left" data-mux="customScroll" data-target="html" id="ResultsContainer">
#     <div class="scrollable" id="ResultsScrollable">
#      <script type="application/ld+json">
#       {"@context":"https://schema.org","@type":"ItemList","mainEntityOfPage":{
#             "@type":"CollectionPage","@id":"https://www.monster.com/jobs/search/?q=data-scientist&amp;where=united-states"
#             }
#             ,"itemListElement":[
#
#                  {"@type":"ListItem","position":1,"url":"https://job-openings.monster.com/senior-data-scientist-phd-saint-louis-mo-us-cybercoders/219436342"}
#                     ,
#                  {"@type":"ListItem","position":2,"url":""}
#                     ,
#                  {"@type":"ListItem","position":3,"url":"https://job-openings.monster.com/data-scientist-hampton-va-us-dcs-corp/219410230"}
# ...

# %%
job_elems = results.find_all('section', class_='card-content')

# %%
for job_elem in job_elems:
    print(job_elem, end='\n'*2)
# Out:
# <section class="card-content" data-jobid="219436342" data-postingid="b1b50049-5fef-4317-8fbc-3241f45085cb" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
# <div class="flex-row">
# <div class="mux-company-logo thumbnail is-loaded">
# <img alt="CyberCoders" src="https://media.newjobs.com/clu/xcyb/xcyberc3x/branding/6344/CyberCoders-logo.jpg"/>
# </div>
# <div class="summary">
# <header class="card-header">
# ...

# %%
for job_elem in job_elems:
    # Each job_elem is a new BeautifulSoup object.
    # You can use the same methods on it as you did before.
    title_elem = job_elem.find('h2', class_='title')
    company_elem = job_elem.find('div', class_='company')
    location_elem = job_elem.find('div', class_='location')
    print(title_elem)
    print(company_elem)
    print(location_elem)
    print()
# Out:
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="660" data-m_impr_j_coc="xcyberc3x" data-m_impr_j_jawsid="442211301" data-m_impr_j_jobid="219436342" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="38.6762" data-m_impr_j_lid="497" data-m_impr_j_long="-90.379" data-m_impr_j_occid="11969" data-m_impr_j_p="1" data-m_impr_j_postingid="b1b50049-5fef-4317-8fbc-3241f45085cb" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="d93f257f-997b-4a3f-ab05-86edea713bee" href="https://job-openings.monster.com/senior-data-scientist-phd-saint-louis-mo-us-cybercoders/219436342" onclick="clickJobTitle('plid=497&amp;pcid=660&amp;poccid=11969','data scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Senior Data Scientist (PhD)&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xcyberc3x_CyberCoders&quot;,&quot;eVar31&qu
# ...

# %%
for job_elem in job_elems:
    title_elem = job_elem.find('h2', class_='title')
    company_elem = job_elem.find('div', class_='company')
    location_elem = job_elem.find('div', class_='location')
    if None in (title_elem, company_elem, location_elem):
        continue
    print(title_elem.text)
    print(company_elem.text)
    print(location_elem.text)
    print()
# Out:
# Senior Data Scientist (PhD)
#
#
# CyberCoders
#
#
#
#
#
# Saint Louis, MO
#
#
#
# Data Scientist
#
#
# DCS Corp
#
#
#
#
#
# Hampton, VA
#
#
#
# Senior Data Scientist, Precision Health Innovation
#
#
# Astellas
#
#
#
#
#
# San Francisco, CA
#
#
#
# Data Scientist
#
#
# Honeywell
#
#
#
#
#
# Atlanta, GA
#
#
#
# Data Scientist
#
#
# Tasacom
#
#
#
#
#
# Redmond, WA
#
#
#
# Data Scientist
#
#
# LexisNexis Risk Solutions, Inc.
#
#
#
#
#
# Alpharetta, GA
#
#
#
# DATA SCIENTIST
#
#
# OSPREYDATA, INC.
#
#
#
#
#
# SAN JUAN CAPISTRANO, CA
#
#
#
# Data Scientist I
#
#
# LexisNexis USA
#
#
#
#
#
# Raleigh, NC
#
#
#
# Engineering and Data Scientist Professionals
#
#
# Engineering Technology Associates
#
#
#
#
#
# Troy, MI
#
#
#
# Senior Data Scientist / Engineer
#
#
# Electronic Warfare Associates
#
#
#
#
#
# HERNDON, VA
#
#
#
# Sr Machine Learning Scientist - Prime Video Recommendations
#
#
# Amazon Corporate LLC
#
#
#
#
#
# Seattle, WA
#
#
#
# Data Scientist with TS/SCI with Polygraph
#
#
# ...

# %%
datascientist_jobs = results.find_all('h2', string='Data Scientist')

# %%
datascientist_jobs = results.find_all('h2',
                               string=lambda text: "data" in text.lower())

for d_job in datascientist_jobs:
    link = d_job.find('a')['href']
    print(d_job.text.strip())
    print(f"Apply here: {link}\n")
# Out:
# Senior Data Scientist (PhD)
# Apply here: https://job-openings.monster.com/senior-data-scientist-phd-saint-louis-mo-us-cybercoders/219436342
#
# Data Scientist
# Apply here: https://job-openings.monster.com/data-scientist-hampton-va-us-dcs-corp/219410230
#
# Senior Data Scientist, Precision Health Innovation
# Apply here: https://job-openings.monster.com/senior-data-scientist-precision-health-innovation-san-francisco-ca-us-astellas/218865345
#
# Data Scientist
# Apply here: https://job-openings.monster.com/data-scientist-atlanta-ga-us-honeywell/219417786
#
# Data Scientist
# Apply here: https://job-openings.monster.com/data-scientist-redmond-wa-us-tasacom/219387341
#
# Data Scientist
# Apply here: https://job-openings.monster.com/data-scientist-alpharetta-ga-us-lexisnexis-risk-solutions-inc/219337872
#
# DATA SCIENTIST
# Apply here: https://job-openings.monster.com/data-scientist-san-juan-capistrano-ca-us-ospreydata-inc/219272094
#
# Data Scientist I
# ...
